# %%
from mcw_utils.donut_quant import quantify_within_well, quantify_within_timepoint
from pathlib import Path

# This is the path to your files, in here they are in the example subfolder
local_path = Path('./example')

# %%
# Run either normalizing within well
quantify_within_well(local_path, l=6, u=6, w=41, step=56, show_plot=True)
# Out:
# Reading inputs...
# Cropping and encoding wells...
# Processing example/exp_before_drug/imgs/0006238_01_RGBTrans.TIF at time -1
# /home/msochor/repos/McFallLab/mcw_utils/donut_quant/donut_quant.py:230: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   sample_df.fillna("", inplace=True)
# /home/msochor/repos/McFallLab/mcw_utils/donut_quant/donut_quant.py:231: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   drug_df.fillna("", inplace=True)
# ...

# %%
# or normalizing within timepoint
quantify_within_timepoint(local_path, l=6, u=6, w=41, step=56, show_plot=True)
# Out:
# /home/msochor/repos/McFallLab/mcw_utils/donut_quant/donut_quant.py:230: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   sample_df.fillna("", inplace=True)
# /home/msochor/repos/McFallLab/mcw_utils/donut_quant/donut_quant.py:231: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   drug_df.fillna("", inplace=True)
# Processing example/exp_before_drug/imgs/0006238_01_RGBTrans.TIF at time -1
# Processing example/exp_12hr/imgs/0006246_01_RGBTrans.TIF at time 12
# Results saved to: example/resnet50_cosine_similarity_within_timepoints.csv
# Pickle saved to: example/resnet50_cosine_similarity_within_timepoints.pkl
# ...
